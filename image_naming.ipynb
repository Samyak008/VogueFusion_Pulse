# %%
import os

def rename_images(folder_path):
    # List all files in the folder
    files = os.listdir(folder_path)
    
    # Filter only .jpg files
    images = [f for f in files if f.lower().endswith('.jpg')]
    
    # Sort images by name (optional)
    images.sort()

    # Rename the images with ordered names
    for index, image in enumerate(images):
        # Generate the new file name
        new_name = f"image_{index+1}.jpg"
        
        # Get the full path of the current image and the new name
        old_path = os.path.join(folder_path, image)
        new_path = os.path.join(folder_path, new_name)
        
        # Rename the image
        os.rename(old_path, new_path)
        print(f"Renamed {image} to {new_name}")

# Usage example:
folder_path = "./saree"  # Replace with the actual folder path
rename_images(folder_path)
# Out:
# Renamed IMG-20241110-WA0001.jpg to image_1.jpg
# Renamed IMG-20241110-WA0002.jpg to image_2.jpg
# Renamed IMG-20241110-WA0003.jpg to image_3.jpg
# Renamed IMG-20241110-WA0004.jpg to image_4.jpg
# Renamed IMG-20241110-WA0005.jpg to image_5.jpg
# Renamed IMG-20241110-WA0006.jpg to image_6.jpg
# Renamed IMG-20241110-WA0007.jpg to image_7.jpg
# Renamed IMG-20241110-WA0008.jpg to image_8.jpg
# Renamed IMG-20241110-WA0009.jpg to image_9.jpg
# Renamed IMG-20241110-WA0010.jpg to image_10.jpg
# Renamed IMG-20241110-WA0011.jpg to image_11.jpg
# Renamed IMG-20241110-WA0012.jpg to image_12.jpg
# Renamed IMG-20241110-WA0013.jpg to image_13.jpg
# Renamed IMG-20241116-WA0010.jpg to image_14.jpg
# Renamed IMG-20241116-WA0011.jpg to image_15.jpg
# Renamed IMG-20241116-WA0012.jpg to image_16.jpg
# Renamed IMG-20241116-WA0013.jpg to image_17.jpg
# Renamed IMG-20241116-WA0014.jpg to image_18.jpg
# Renamed IMG-20241116-WA0015.jpg to image_19.jpg
# Renamed IMG-20241116-WA0016.jpg to image_20.jpg
# Renamed IMG-20241116-WA0017.jpg to image_21.jpg
# Renamed IMG-20241116-WA0018.jpg to image_22.jpg
# Renamed IMG-20241116-WA0019.jpg to image_23.jpg
# Renamed IMG-20241116-WA0020.jpg to image_24.jpg
# Renamed IMG-20241116-WA0021.jpg to image_25.jpg
# Renamed IMG-20241116-WA0022.jpg to image_26.jpg
# Renamed IMG-20241116-WA0023.jpg to image_27.jpg
# Renamed IMG-20241116-WA0024.jpg to image_28.jpg
# Renamed IMG-20241116-WA0025.jpg to image_29.jpg
# Renamed IMG-20241116-WA0026.jpg to image_30.jpg
# Renamed IMG-20241116-WA0027.jpg to image_31.jpg
# Renamed IMG-20241116-WA0028.jpg to image_32.jpg
# Renamed IMG-20241116-WA0029.jpg to image_33.jpg
# Renamed IMG-20241116-WA0030.jpg to image_34.jpg
# Renamed IMG-20241116-WA0031.jpg to image_35.jpg
# Renamed IMG-20241116-WA0032.jpg to image_36.jpg
# Renamed IMG-20241116-WA0033.jpg to image_37.jpg
# Renamed IMG-20241116-WA0034.jpg to image_38.jpg
# Renamed IMG-20241116-WA0035.jpg to image_39.jpg
# Renamed IMG-20241116-WA0036.jpg to image_40.jpg
# Renamed IMG-20241116-WA0037.jpg to image_41.jpg
# Renamed IMG-20241116-WA0038.jpg to image_42.jpg
# Renamed IMG-20241116-WA0039.jpg to image_43.jpg
# Renamed IMG-20241116-WA0040.jpg to image_44.jpg
# Renamed IMG-20241116-WA0041.jpg to image_45.jpg
# Renamed IMG-20241116-WA0042.jpg to image_46.jpg
# Renamed IMG-20241116-WA0043.jpg to image_47.jpg
# Renamed IMG-20241116-WA0044.jpg to image_48.jpg
# Renamed IMG-20241116-WA0045.jpg to image_49.jpg
# Renamed IMG-20241116-WA0046.jpg to image_50.jpg
# Renamed IMG-20241116-WA0047.jpg to image_51.jpg
# Renamed IMG-20241116-WA0048.jpg to image_52.jpg
# Renamed IMG-20241116-WA0049.jpg to image_53.jpg
# Renamed IMG-20241116-WA0050.jpg to image_54.jpg
# Renamed IMG-20241211-WA0024.jpg to image_55.jpg
# Renamed IMG-20241211-WA0025.jpg to image_56.jpg
# Renamed IMG-20241211-WA0026.jpg to image_57.jpg
# Renamed IMG-20241211-WA0027.jpg to image_58.jpg
# Renamed IMG-20241211-WA0028.jpg to image_59.jpg
# Renamed IMG-20241211-WA0029.jpg to image_60.jpg
# Renamed IMG-20241211-WA0030.jpg to image_61.jpg
# Renamed IMG-20241211-WA0031.jpg to image_62.jpg
# Renamed IMG-20241211-WA0032.jpg to image_63.jpg
# Renamed IMG-20241211-WA0033.jpg to image_64.jpg
# Renamed IMG-20241211-WA0034.jpg to image_65.jpg
# Renamed IMG-20241211-WA0035.jpg to image_66.jpg
# Renamed IMG-20241211-WA0036.jpg to image_67.jpg
# Renamed IMG-20241211-WA0037.jpg to image_68.jpg
# Renamed IMG-20241211-WA0038.jpg to image_69.jpg
# Renamed IMG-20241211-WA0039.jpg to image_70.jpg
# Renamed IMG-20241211-WA0040.jpg to image_71.jpg
# Renamed IMG-20241211-WA0041.jpg to image_72.jpg
# Renamed IMG-20241211-WA0042.jpg to image_73.jpg
# Renamed IMG-20241211-WA0043.jpg to image_74.jpg
# Renamed IMG-20241211-WA0044.jpg to image_75.jpg
# Renamed IMG-20241211-WA0045.jpg to image_76.jpg
# Renamed IMG-20241211-WA0046.jpg to image_77.jpg
# Renamed IMG-20241211-WA0047.jpg to image_78.jpg
# Renamed IMG-20241211-WA0048.jpg to image_79.jpg
# Renamed IMG-20241211-WA0049.jpg to image_80.jpg
# Renamed IMG-20241211-WA0050.jpg to image_81.jpg
# Renamed IMG-20241211-WA0051.jpg to image_82.jpg

# %%
import os

def generate_text_files_for_images(folder_path):
    # Create a folder for labels if it doesn't exist
    labels_folder = os.path.join(folder_path, 'labels')
    if not os.path.exists(labels_folder):
        os.makedirs(labels_folder)

    # List all files in the folder
    files = os.listdir(folder_path)
    
    # Filter only .jpg files
    images = [f for f in files if f.lower().endswith('.jpg')]
    
    # Sort images by name (optional)
    images.sort()

    # Generate corresponding text files for each image in the labels folder
    for index, image in enumerate(images):
        # Generate the new text file name based on the image name
        txt_name = f"image_{index+1}.txt"
        
        # Get the full path for the .txt file in the labels folder
        txt_path = os.path.join(labels_folder, txt_name)
        
        # Create a .txt file (this example creates empty files, you can add content as needed)
        with open(txt_path, 'w') as f:
            f.write(f"This is the text file for {image}.")  # Example content; modify as needed
        
        print(f"Generated {txt_name} in {labels_folder}")

# Usage example:
folder_path = "./Saree"  # Replace with the actual folder path
generate_text_files_for_images(folder_path)
# Out:
# Generated image_1.txt in ./Saree\labels
